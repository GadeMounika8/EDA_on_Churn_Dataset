# %% [markdown]
# # Importing all required Libraries:

# %%
# importing all required python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the Dataset:

# %%
# reading the csv file
df = pd.read_csv(r"C:\Users\mouni\Downloads\churn_dataset.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # Data Cleaning:

# %%
# Checking number of duplicates in a DF
df.duplicated().sum()
# Out:
# 0

# %%
# Checking Null Values count of each column in a DataFrame
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# changing the datatype of TotalCharges Column from object to float
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
# returning all the information of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# checking the Null Values count in each column
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df = df.drop('customerID', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   object
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   object
#  3   Dependents        7032 non-null   object
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   object
# ...

# %%
# removing outliers in tenure column by using IQR Method
Q1 = df['tenure'].quantile(0.25)
Q3 = df['tenure'].quantile(0.75)
IQR = Q3 - Q1
bmi_lower_bound = Q1 - 1.5*IQR
bmi_upper_bound = Q3 + 1.5*IQR
df = df[(df['tenure'] > bmi_lower_bound)&(df['tenure']<bmi_upper_bound)]
print(df.shape)
# Out:
# (7032, 20)

# %%
# removing outliers in MonthlyCharges column by using IQR Method
Q1 = df['MonthlyCharges'].quantile(0.25)
Q3 = df['MonthlyCharges'].quantile(0.75)
IQR = Q3 - Q1
bmi_lower_bound = Q1 - 1.5*IQR
bmi_upper_bound = Q3 + 1.5*IQR
df = df[(df['MonthlyCharges'] > bmi_lower_bound)&(df['MonthlyCharges']<bmi_upper_bound)]
print(df.shape)
# Out:
# (7032, 20)

# %%
# removing outliers in TotalCharges column by using IQR Method
Q1 = df['TotalCharges'].quantile(0.25)
Q3 = df['TotalCharges'].quantile(0.75)
IQR = Q3 - Q1
bmi_lower_bound = Q1 - 1.5*IQR
bmi_upper_bound = Q3 + 1.5*IQR
df = df[(df['TotalCharges'] > bmi_lower_bound)&(df['TotalCharges']<bmi_upper_bound)]
print(df.shape)
# Out:
# (7032, 20)

# %%
# Top 5 Records
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df.shape
# Out:
# (7032, 20)

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   object
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   object
#  3   Dependents        7032 non-null   object
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df['Churn'].value_counts()
# Out:
# No     5163
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# # Identifying and segregating the Input Variables (x) and Output Variables(y):

# %%
y = df['Churn']
X = df.drop("Churn",axis=1)

# %% [markdown]
# # Splitting the data into Training Data and Testing Data:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (5274, 19) (5274,)
# (1758, 19) (1758,)

# %% [markdown]
# # Data Preparation on Training Data:

# %% [markdown]
# # Applying Label Encoding Technique on numerical features in Training Data:

# %%
X_train_cat = X_train.select_dtypes(include = ['object'])
X_train_cat.head()
# Out:
#       gender Partner Dependents PhoneService MultipleLines InternetService  \
# 3540  Female     Yes        Yes          Yes            No     Fiber optic
# 3504    Male     Yes        Yes          Yes            No              No
# 6715  Female      No         No          Yes           Yes     Fiber optic
# 2866  Female      No         No          Yes            No     Fiber optic
# 6609    Male      No         No          Yes            No              No
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 3540                  Yes                  Yes                  Yes
# 3504  No internet service  No internet service  No internet service
# 6715                   No                   No                  Yes
# 2866                   No                  Yes                   No
# 6609  No internet service  No internet service  No internet service
#
#               TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
X_train_cat_le = pd.DataFrame(index = X_train_cat.index)
X_train_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [3540, 3504, 6715, 2866, 6609]

# %%
df['gender'].value_counts()
# Out:
# Male      3549
# Female    3483
# Name: gender, dtype: int64

# %%
gender_le_encoder = {'Male':0, 'Female':1}
X_train_cat_le['gender'] = X_train_cat['gender'].apply(lambda X:gender_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender
# 3540       1
# 3504       0
# 6715       1
# 2866       1
# 6609       0

# %%
df['Partner'].value_counts()
# Out:
# No     3639
# Yes    3393
# Name: Partner, dtype: int64

# %%
Partner_le_encoder = {'No':0, 'Yes':1}
X_train_cat_le['Partner'] = X_train_cat['Partner'].apply(lambda X:Partner_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner
# 3540       1        1
# 3504       0        1
# 6715       1        0
# 2866       1        0
# 6609       0        0

# %%
df['Dependents'].value_counts()
# Out:
# No     4933
# Yes    2099
# Name: Dependents, dtype: int64

# %%
Dependents_le_encoder = {'No':0, 'Yes':1}
X_train_cat_le['Dependents'] = X_train_cat['Dependents'].apply(lambda X:Dependents_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner  Dependents
# 3540       1        1           1
# 3504       0        1           1
# 6715       1        0           0
# 2866       1        0           0
# 6609       0        0           0

# %%
df['PhoneService'].value_counts()
# Out:
# Yes    6352
# No      680
# Name: PhoneService, dtype: int64

# %%
PhoneService_le_encoder = {'No':0, 'Yes':1}
X_train_cat_le['PhoneService'] = X_train_cat['PhoneService'].apply(lambda X:PhoneService_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner  Dependents  PhoneService
# 3540       1        1           1             1
# 3504       0        1           1             1
# 6715       1        0           0             1
# 2866       1        0           0             1
# 6609       0        0           0             1

# %%
df['MultipleLines'].value_counts()
# Out:
# No                  3385
# Yes                 2967
# No phone service     680
# Name: MultipleLines, dtype: int64

# %%
MultipleLines_le_encoder = {'No':0, 'Yes':1, 'No phone service':2}
X_train_cat_le['MultipleLines'] = X_train_cat['MultipleLines'].apply(lambda X:MultipleLines_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner  Dependents  PhoneService  MultipleLines
# 3540       1        1           1             1              0
# 3504       0        1           1             1              0
# 6715       1        0           0             1              1
# 2866       1        0           0             1              0
# 6609       0        0           0             1              0

# %%
df['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2416
# No             1520
# Name: InternetService, dtype: int64

# %%
InternetService_le_encoder = {'No':0, 'Fiber optic':1, 'DSL':2}
X_train_cat_le['InternetService'] = X_train_cat['InternetService'].apply(lambda X:InternetService_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner  Dependents  PhoneService  MultipleLines  \
# 3540       1        1           1             1              0
# 3504       0        1           1             1              0
# 6715       1        0           0             1              1
# 2866       1        0           0             1              0
# 6609       0        0           0             1              0
#
#       InternetService
# 3540                1
# 3504                0
# 6715                1
# 2866                1
# 6609                0

# %%
df['OnlineSecurity'].value_counts()
# Out:
# No                     3497
# Yes                    2015
# No internet service    1520
# Name: OnlineSecurity, dtype: int64

# %%
OnlineSecurity_le_encoder = {'No':0, 'Yes':1, 'No internet service':2}
X_train_cat_le['OnlineSecurity'] = X_train_cat['OnlineSecurity'].apply(lambda X:OnlineSecurity_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner  Dependents  PhoneService  MultipleLines  \
# 3540       1        1           1             1              0
# 3504       0        1           1             1              0
# 6715       1        0           0             1              1
# 2866       1        0           0             1              0
# 6609       0        0           0             1              0
#
#       InternetService  OnlineSecurity
# 3540                1               1
# 3504                0               2
# 6715                1               0
# 2866                1               0
# 6609                0               2

# %%
df['OnlineBackup'].value_counts()
# Out:
# No                     3087
# Yes                    2425
# No internet service    1520
# Name: OnlineBackup, dtype: int64

# %%
OnlineBackup_le_encoder = {'No':0, 'Yes':1, 'No internet service':2}
X_train_cat_le['OnlineBackup'] = X_train_cat['OnlineBackup'].apply(lambda X:OnlineBackup_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner  Dependents  PhoneService  MultipleLines  \
# 3540       1        1           1             1              0
# 3504       0        1           1             1              0
# 6715       1        0           0             1              1
# 2866       1        0           0             1              0
# 6609       0        0           0             1              0
#
#       InternetService  OnlineSecurity  OnlineBackup
# 3540                1               1             1
# 3504                0               2             2
# 6715                1               0             0
# 2866                1               0             1
# 6609                0               2             2

# %%
df['DeviceProtection'].value_counts()
# Out:
# No                     3094
# Yes                    2418
# No internet service    1520
# Name: DeviceProtection, dtype: int64

# %%
DeviceProtection_le_encoder = {'No':0, 'Yes':1, 'No internet service':2}
X_train_cat_le['DeviceProtection'] = X_train_cat['DeviceProtection'].apply(lambda X:DeviceProtection_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner  Dependents  PhoneService  MultipleLines  \
# 3540       1        1           1             1              0
# 3504       0        1           1             1              0
# 6715       1        0           0             1              1
# 2866       1        0           0             1              0
# 6609       0        0           0             1              0
#
#       InternetService  OnlineSecurity  OnlineBackup  DeviceProtection
# 3540                1               1             1                 1
# 3504                0               2             2                 2
# 6715                1               0             0                 1
# 2866                1               0             1                 0
# 6609                0               2             2                 2

# %%
df['TechSupport'].value_counts()
# Out:
# No                     3472
# Yes                    2040
# No internet service    1520
# Name: TechSupport, dtype: int64

# %%
TechSupport_le_encoder = {'No':0, 'Yes':1, 'No internet service':2}
X_train_cat_le['TechSupport'] = X_train_cat['TechSupport'].apply(lambda X:TechSupport_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner  Dependents  PhoneService  MultipleLines  \
# 3540       1        1           1             1              0
# 3504       0        1           1             1              0
# 6715       1        0           0             1              1
# 2866       1        0           0             1              0
# 6609       0        0           0             1              0
#
#       InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 3540                1               1             1                 1
# 3504                0               2             2                 2
# 6715                1               0             0                 1
# 2866                1               0             1                 0
# 6609                0               2             2                 2
#
#       TechSupport
# 3540            1
# 3504            2
# 6715            0
# 2866            0
# 6609            2

# %%
df['StreamingTV'].value_counts()
# Out:
# No                     2809
# Yes                    2703
# No internet service    1520
# Name: StreamingTV, dtype: int64

# %%
StreamingTV_le_encoder = {'No':0, 'Yes':1, 'No internet service':2}
X_train_cat_le['StreamingTV'] = X_train_cat['StreamingTV'].apply(lambda X:StreamingTV_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner  Dependents  PhoneService  MultipleLines  \
# 3540       1        1           1             1              0
# 3504       0        1           1             1              0
# 6715       1        0           0             1              1
# 2866       1        0           0             1              0
# 6609       0        0           0             1              0
#
#       InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 3540                1               1             1                 1
# 3504                0               2             2                 2
# 6715                1               0             0                 1
# 2866                1               0             1                 0
# 6609                0               2             2                 2
#
#       TechSupport  StreamingTV
# 3540            1            1
# 3504            2            2
# 6715            0            1
# 2866            0            0
# ...

# %%
df['StreamingMovies'].value_counts()
# Out:
# No                     2781
# Yes                    2731
# No internet service    1520
# Name: StreamingMovies, dtype: int64

# %%
StreamingMovies_le_encoder = {'No':0, 'Yes':1, 'No internet service':2}
X_train_cat_le['StreamingMovies'] = X_train_cat['StreamingMovies'].apply(lambda X:StreamingMovies_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner  Dependents  PhoneService  MultipleLines  \
# 3540       1        1           1             1              0
# 3504       0        1           1             1              0
# 6715       1        0           0             1              1
# 2866       1        0           0             1              0
# 6609       0        0           0             1              0
#
#       InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 3540                1               1             1                 1
# 3504                0               2             2                 2
# 6715                1               0             0                 1
# 2866                1               0             1                 0
# 6609                0               2             2                 2
#
#       TechSupport  StreamingTV  StreamingMovies
# 3540            1            1                1
# 3504            2            2                2
# ...

# %%
df['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1685
# One year          1472
# Name: Contract, dtype: int64

# %%
Contract_le_encoder = {'Month-to-month':1, 'One year':2, 'Two year':3}
X_train_cat_le['Contract'] = X_train_cat['Contract'].apply(lambda X:Contract_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner  Dependents  PhoneService  MultipleLines  \
# 3540       1        1           1             1              0
# 3504       0        1           1             1              0
# 6715       1        0           0             1              1
# 2866       1        0           0             1              0
# 6609       0        0           0             1              0
#
#       InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 3540                1               1             1                 1
# 3504                0               2             2                 2
# 6715                1               0             0                 1
# 2866                1               0             1                 0
# 6609                0               2             2                 2
#
#       TechSupport  StreamingTV  StreamingMovies  Contract
# 3540            1            1                1         3
# ...

# %%
df['PaperlessBilling'].value_counts()
# Out:
# Yes    4168
# No     2864
# Name: PaperlessBilling, dtype: int64

# %%
PaperlessBilling_le_encoder = {'No':0, 'Yes':1, 'No internet service':2}
X_train_cat_le['PaperlessBilling'] = X_train_cat['PaperlessBilling'].apply(lambda X:PaperlessBilling_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner  Dependents  PhoneService  MultipleLines  \
# 3540       1        1           1             1              0
# 3504       0        1           1             1              0
# 6715       1        0           0             1              1
# 2866       1        0           0             1              0
# 6609       0        0           0             1              0
#
#       InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 3540                1               1             1                 1
# 3504                0               2             2                 2
# 6715                1               0             0                 1
# 2866                1               0             1                 0
# 6609                0               2             2                 2
#
#       TechSupport  StreamingTV  StreamingMovies  Contract  PaperlessBilling
# 3540            1            1                1         3                 1
# ...

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1604
# Bank transfer (automatic)    1542
# Credit card (automatic)      1521
# Name: PaymentMethod, dtype: int64

# %%
PaymentMethod_le_encoder = {'Electronic check':1, 'Mailed check':2, 'Bank transfer (automatic)':3, 'Credit card (automatic)':4}
X_train_cat_le['PaymentMethod'] = X_train_cat['PaymentMethod'].apply(lambda X:PaymentMethod_le_encoder[X])
X_train_cat_le.head()
# Out:
#       gender  Partner  Dependents  PhoneService  MultipleLines  \
# 3540       1        1           1             1              0
# 3504       0        1           1             1              0
# 6715       1        0           0             1              1
# 2866       1        0           0             1              0
# 6609       0        0           0             1              0
#
#       InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 3540                1               1             1                 1
# 3504                0               2             2                 2
# 6715                1               0             0                 1
# 2866                1               0             1                 0
# 6609                0               2             2                 2
#
#       TechSupport  StreamingTV  StreamingMovies  Contract  PaperlessBilling  \
# 3540            1            1                1         3                 1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   object
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   object
#  3   Dependents        7032 non-null   object
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   object
# ...

# %%
X_train_num = X_train.select_dtypes(include =['float64', 'int64'])
X_train_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 3540              0      72          108.65       7726.35
# 3504              0      68           19.95       1377.70
# 6715              0      11           89.20        990.30
# 2866              0      12           84.60       1017.35
# 6609              0       1           20.10         20.10

# %% [markdown]
# # Concatenating both Numerical and Categorical Features of Traing data:

# %%
X_train_transformed = pd.concat([X_train_num, X_train_cat_le], axis = 1)
X_train_transformed.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender  Partner  \
# 3540              0      72          108.65       7726.35       1        1
# 3504              0      68           19.95       1377.70       0        1
# 6715              0      11           89.20        990.30       1        0
# 2866              0      12           84.60       1017.35       1        0
# 6609              0       1           20.10         20.10       0        0
#
#       Dependents  PhoneService  MultipleLines  InternetService  \
# 3540           1             1              0                1
# 3504           1             1              0                0
# 6715           0             1              1                1
# 2866           0             1              0                1
# 6609           0             1              0                0
#
#       OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# ...

# %% [markdown]
# # Building a Model by using Decision Tree classifier Algorithm:

# %%
from sklearn.tree import DecisionTreeClassifier
DT_classifier_object = DecisionTreeClassifier(max_depth = 4)
DT_classifier_object.fit(X_train_transformed, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
# Classes known to classifier
DT_classifier_object.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Number of features seen by algo during training
DT_classifier_object.n_features_in_
# Out:
# 19

# %%
# Names of features seen during training
DT_classifier_object.feature_names_in_
# Out:
# array(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges',
#        'gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'],
#       dtype=object)

# %% [markdown]
# # Data Preparation on Test Data:

# %%
X_test_num =X_test.select_dtypes(include = ['float64', 'int64'])
X_test_num.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 5561              0       1           20.65         20.65
# 5814              0      16           20.60        330.25
# 2645              0       1           19.80         19.80
# 3983              0       1           24.25         24.25
# 6438              1       1           74.40         74.40

# %% [markdown]
# # Applying Label Encoding Technique on Categorical Features in Test Data:

# %%
X_test_cat = X_test.select_dtypes(include = 'object')
X_test_cat.head()
# Out:
#       gender Partner Dependents PhoneService     MultipleLines  \
# 5561    Male      No         No          Yes                No
# 5814    Male      No         No          Yes                No
# 2645  Female      No         No          Yes                No
# 3983    Male      No         No           No  No phone service
# 6438    Male      No         No          Yes               Yes
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# 5561              No  No internet service  No internet service
# 5814              No  No internet service  No internet service
# 2645              No  No internet service  No internet service
# 3983             DSL                   No                   No
# 6438     Fiber optic                   No                   No
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 5561  No internet service  No internet service  No internet service
# ...

# %%
X_test_cat_le = pd.DataFrame(index = X_test_cat.index)
X_test_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [5561, 5814, 2645, 3983, 6438]

# %%
X_test_cat_le['gender'] = X_test_cat['gender'].apply(lambda X:gender_le_encoder[X])
X_test_cat_le['Partner'] = X_test_cat['Partner'].apply(lambda X:Partner_le_encoder[X])
X_test_cat_le['Dependents'] = X_test_cat['Dependents'].apply(lambda X:Dependents_le_encoder[X])
X_test_cat_le['PhoneService'] = X_test_cat['PhoneService'].apply(lambda X:PhoneService_le_encoder[X])
X_test_cat_le['MultipleLines'] = X_test_cat['MultipleLines'].apply(lambda X:MultipleLines_le_encoder[X])
X_test_cat_le['InternetService'] = X_test_cat['InternetService'].apply(lambda X:InternetService_le_encoder[X])
X_test_cat_le['OnlineSecurity'] = X_test_cat['OnlineSecurity'].apply(lambda X:OnlineSecurity_le_encoder[X])
X_test_cat_le['OnlineBackup'] = X_test_cat['OnlineBackup'].apply(lambda X:OnlineBackup_le_encoder[X])
X_test_cat_le['DeviceProtection'] = X_test_cat['DeviceProtection'].apply(lambda X:DeviceProtection_le_encoder[X])
X_test_cat_le['TechSupport'] = X_test_cat['TechSupport'].apply(lambda X:TechSupport_le_encoder[X])
X_test_cat_le['StreamingTV'] = X_test_cat['StreamingTV'].apply(lambda X:StreamingTV_le_encoder[X])
X_test_cat_le['StreamingMovies'] = X_test_cat['StreamingMovies'].apply(lambda X:StreamingMovies_le_encoder[X])
X_test_cat_le['Contract'] = X_test_cat['Contract'].apply(lambda X:Contract_le_encoder[X])
X_test_cat_le['PaperlessBilling'] = X_test_cat['PaperlessBilling'].apply(lambda X:PaperlessBilling_le_encoder[X])
X_test_cat_le['PaymentMethod'] = X_test_cat['PaymentMethod'].apply(lambda X:PaymentMethod_le_encoder[X])
X_test_cat_le.head()
# Out:
#       gender  Partner  Dependents  PhoneService  MultipleLines  \
# 5561       0        0           0             1              0
# 5814       0        0           0             1              0
# 2645       1        0           0             1              0
# 3983       0        0           0             0              2
# 6438       0        0           0             1              1
#
#       InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 5561                0               2             2                 2
# 5814                0               2             2                 2
# 2645                0               2             2                 2
# 3983                2               0             0                 0
# 6438                1               0             0                 0
#
#       TechSupport  StreamingTV  StreamingMovies  Contract  PaperlessBilling  \
# 5561            2            2                2         1                 0
# ...

# %% [markdown]
# # Concatenating both Numerical and Categorical Features of Traing data:

# %%
X_test_transformed = pd.concat([X_test_num, X_test_cat_le], axis = 1)
X_test_transformed.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender  Partner  \
# 5561              0       1           20.65         20.65       0        0
# 5814              0      16           20.60        330.25       0        0
# 2645              0       1           19.80         19.80       1        0
# 3983              0       1           24.25         24.25       0        0
# 6438              1       1           74.40         74.40       0        0
#
#       Dependents  PhoneService  MultipleLines  InternetService  \
# 5561           0             1              0                0
# 5814           0             1              0                0
# 2645           0             1              0                0
# 3983           0             0              2                2
# 6438           0             1              1                1
#
#       OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# ...

# %%
X_train_transformed.head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender  Partner  \
# 3540              0      72          108.65       7726.35       1        1
# 3504              0      68           19.95       1377.70       0        1
# 6715              0      11           89.20        990.30       1        0
# 2866              0      12           84.60       1017.35       1        0
# 6609              0       1           20.10         20.10       0        0
#
#       Dependents  PhoneService  MultipleLines  InternetService  \
# 3540           1             1              0                1
# 3504           1             1              0                0
# 6715           0             1              1                1
# 2866           0             1              0                1
# 6609           0             1              0                0
#
#       OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# ...

# %%
X_train.shape
# Out:
# (5274, 19)

# %%
X_test.shape
# Out:
# (1758, 19)

# %%
X_train_cat_le.shape
# Out:
# (5274, 15)

# %%
X_test_cat_le.shape
# Out:
# (1758, 15)

# %%
X_train_transformed.shape
# Out:
# (5274, 19)

# %%
X_test_transformed.shape
# Out:
# (1758, 19)

# %% [markdown]
# # Predictions:

# %%
y_test_pred = DT_classifier_object.predict(X_test_transformed)

# %% [markdown]
# # Evaluation of a Model Performance:

# %% [markdown]
# # 1. Accuracy:

# %%
# calculate accuracy of class predictions
from sklearn import metrics
metrics.accuracy_score(y_test, y_test_pred)
# Out:
# 0.7866894197952219

# %% [markdown]
# # 2. Confusion Metric:

# %%
con_metric = metrics.confusion_matrix(y_test, y_test_pred)
con_metric
# Out:
# array([[1204,  107],
#        [ 268,  179]], dtype=int64)

# %%
#ploting heatmap for confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(con_metric, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # Visualization of the DT Model:

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(40,25))

f = plot_tree(DT_classifier_object, feature_names = X_train.columns, 
              class_names = ['Yes', 'No'], 
              filled = True, 
              rounded = True, 
              fontsize = 14
             )
plt.show()

# %% [markdown]
# # Feature Importance:

# %%
DT_classifier_object.feature_importances_
# Out:
# array([0.        , 0.12724685, 0.03820717, 0.02487066, 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.08669173,
#        0.13809609, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.57687873, 0.00470961, 0.00329916])

# %%
plt.figure(figsize=(15,7))

sns.barplot(x = DT_classifier_object.feature_importances_, y = X_train.columns)

plt.show()
